# %%
import tensorflow as tf
import numpy as np
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, Activation, InputLayer, Flatten, Input
from tensorflow.keras.utils import to_categorical
import larq

# %%
#Load data.
(x_train, y_train), (x_test, y_test) = mnist.load_data()
x_train, x_test = x_train / 255.0, x_test / 255.0
y_train=to_categorical(y_train,10)
y_test=to_categorical(y_test,10)
x_train = tf.expand_dims(x_train, axis=-1)
x_test = tf.expand_dims(x_test,axis=-1)
# Out:
# 2022-06-08 17:00:39.149466: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 376320000 exceeds 10% of free system memory.

# %%
model=tf.keras.models.load_model("bin_mnist_convnet.h5")
model.summary()

#The loaded model has been compiled, but it can be re-compiled with other parameters if wished.
#model.compile(optimizer='adam',loss='categorical_crossentropy', metrics=['accuracy'])

model.fit(x_train, y_train, epochs=100, batch_size=64)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  quant_conv2d (QuantConv2D)  (None, 26, 26, 32)        320
#
#  max_pooling2d_16 (MaxPoolin  (None, 13, 13, 32)       0
#  g2D)
#
#  quant_conv2d_1 (QuantConv2D  (None, 11, 11, 64)       18496
#  )
#
#  max_pooling2d_17 (MaxPoolin  (None, 5, 5, 64)         0
#  g2D)
#
#  flatten_8 (Flatten)         (None, 1600)              0
#
#  dropout_8 (Dropout)         (None, 1600)              0
#
#  quant_dense (QuantDense)    (None, 10)                16010
#
# =================================================================
# Total params: 34,826
# Trainable params: 34,826
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 938/938 [==============================] - 17s 17ms/step - loss: 4.4039 - accuracy: 0.6323
# Epoch 2/100
# 938/938 [==============================] - 16s 17ms/step - loss: 0.9874 - accuracy: 0.7361
# Epoch 3/100
# 938/938 [==============================] - 16s 17ms/step - loss: 0.9655 - accuracy: 0.7564
# Epoch 4/100
# 938/938 [==============================] - 17s 18ms/step - loss: 0.5959 - accuracy: 0.8327
# Epoch 5/100
# 938/938 [==============================] - 16s 17ms/step - loss: 0.4906 - accuracy: 0.8515
# Epoch 6/100
# 938/938 [==============================] - 16s 17ms/step - loss: 0.4103 - accuracy: 0.8771
# Epoch 7/100
# 938/938 [==============================] - 16s 17ms/step - loss: 0.3902 - accuracy: 0.8819
# Epoch 8/100
# 938/938 [==============================] - 15s 17ms/step - loss: 0.3742 - accuracy: 0.8888
# Epoch 9/100
# 938/938 [==============================] - 16s 17ms/step - loss: 0.3675 - accuracy: 0.8882
# Epoch 10/100
# 938/938 [==============================] - 15s 16ms/step - loss: 0.3416 - accuracy: 0.8955
# Epoch 11/100
# 938/938 [==============================] - 15s 16ms/step - loss: 0.3313 - accuracy: 0.8982
# Epoch 12/100
# 938/938 [==============================] - 15s 16ms/step - loss: 0.3306 - accuracy: 0.8995
# Epoch 13/100
# 938/938 [==============================] - 15s 17ms/step - loss: 0.3184 - accuracy: 0.9013
# Epoch 14/100
# 938/938 [==============================] - 16s 17ms/step - loss: 0.3083 - accuracy: 0.9054
# Epoch 15/100
# 938/938 [==============================] - 16s 17ms/step - loss: 0.3029 - accuracy: 0.9073
# Epoch 16/100
# 938/938 [==============================] - 15s 16ms/step - loss: 0.2915 - accuracy: 0.9125
# Epoch 17/100
# 938/938 [==============================] - 16s 17ms/step - loss: 0.2937 - accuracy: 0.9117
# Epoch 18/100
# 938/938 [==============================] - 16s 17ms/step - loss: 0.2887 - accuracy: 0.9119
# Epoch 19/100
# 938/938 [==============================] - 15s 16ms/step - loss: 0.2820 - accuracy: 0.9141
# Epoch 20/100
# 938/938 [==============================] - 16s 17ms/step - loss: 0.2816 - accuracy: 0.9138
# Epoch 21/100
# 938/938 [==============================] - 16s 17ms/step - loss: 0.2845 - accuracy: 0.9145
# Epoch 22/100
# 938/938 [==============================] - 17s 18ms/step - loss: 0.2804 - accuracy: 0.9157
# Epoch 23/100
# 938/938 [==============================] - 17s 18ms/step - loss: 0.2817 - accuracy: 0.9161
# Epoch 24/100
# 938/938 [==============================] - 15s 16ms/step - loss: 0.2836 - accuracy: 0.9158
# Epoch 25/100
# 938/938 [==============================] - 15s 16ms/step - loss: 0.2787 - accuracy: 0.9154
# Epoch 26/100
# 938/938 [==============================] - 15s 16ms/step - loss: 0.2867 - accuracy: 0.9140
# Epoch 27/100
# 938/938 [==============================] - 16s 17ms/step - loss: 0.2926 - accuracy: 0.9117
# Epoch 28/100
# 938/938 [==============================] - 16s 17ms/step - loss: 0.3089 - accuracy: 0.9096
# Epoch 29/100
# 938/938 [==============================] - 16s 17ms/step - loss: 0.2927 - accuracy: 0.9124
# Epoch 30/100
# 938/938 [==============================] - 16s 17ms/step - loss: 0.3022 - accuracy: 0.9091
# Epoch 31/100
# 938/938 [==============================] - 16s 17ms/step - loss: 0.2927 - accuracy: 0.9099
# Epoch 32/100
# 938/938 [==============================] - 16s 17ms/step - loss: 0.2992 - accuracy: 0.9082
# Epoch 33/100
# 938/938 [==============================] - 16s 17ms/step - loss: 0.2871 - accuracy: 0.9117
# Epoch 34/100
# 938/938 [==============================] - 15s 16ms/step - loss: 0.2807 - accuracy: 0.9149
# Epoch 35/100
# 938/938 [==============================] - 16s 17ms/step - loss: 0.2847 - accuracy: 0.9128
# Epoch 36/100
# 938/938 [==============================] - 16s 17ms/step - loss: 0.2851 - accuracy: 0.9142
# Epoch 37/100
# 938/938 [==============================] - 15s 16ms/step - loss: 0.2906 - accuracy: 0.9114
# Epoch 38/100
# 938/938 [==============================] - 16s 17ms/step - loss: 0.2911 - accuracy: 0.9131
# Epoch 39/100
# 938/938 [==============================] - 16s 17ms/step - loss: 0.2856 - accuracy: 0.9117
# Epoch 40/100
# 938/938 [==============================] - 15s 16ms/step - loss: 0.2820 - accuracy: 0.9133
# Epoch 41/100
# 938/938 [==============================] - 16s 17ms/step - loss: 0.2842 - accuracy: 0.9133
# Epoch 42/100
# 938/938 [==============================] - 16s 17ms/step - loss: 0.2759 - accuracy: 0.9152
# Epoch 43/100
# 938/938 [==============================] - 16s 17ms/step - loss: 0.2810 - accuracy: 0.9146
# Epoch 44/100
# 938/938 [==============================] - 15s 16ms/step - loss: 0.2805 - accuracy: 0.9131
# Epoch 45/100
# 938/938 [==============================] - 15s 16ms/step - loss: 0.2805 - accuracy: 0.9143
# Epoch 46/100
# 938/938 [==============================] - 15s 16ms/step - loss: 0.2718 - accuracy: 0.9158
# Epoch 47/100
# 938/938 [==============================] - 15s 16ms/step - loss: 0.2717 - accuracy: 0.9168
# Epoch 48/100
# 938/938 [==============================] - 15s 16ms/step - loss: 0.2651 - accuracy: 0.9176
# Epoch 49/100
# 938/938 [==============================] - 9s 10ms/step - loss: 0.2754 - accuracy: 0.9166
# Epoch 50/100
# 938/938 [==============================] - 9s 10ms/step - loss: 0.2696 - accuracy: 0.9167
# Epoch 51/100
# 938/938 [==============================] - 9s 10ms/step - loss: 0.2682 - accuracy: 0.9175
# Epoch 52/100
# 938/938 [==============================] - 9s 10ms/step - loss: 0.2696 - accuracy: 0.9170
# Epoch 53/100
# 938/938 [==============================] - 10s 10ms/step - loss: 0.2597 - accuracy: 0.9184
# Epoch 54/100
# 938/938 [==============================] - 9s 10ms/step - loss: 0.2729 - accuracy: 0.9177
# Epoch 55/100
# 938/938 [==============================] - 9s 10ms/step - loss: 0.2658 - accuracy: 0.9182
# Epoch 56/100
# 938/938 [==============================] - 9s 10ms/step - loss: 0.2673 - accuracy: 0.9169
# Epoch 57/100
# 938/938 [==============================] - 9s 10ms/step - loss: 0.2609 - accuracy: 0.9204
# Epoch 58/100
# 938/938 [==============================] - 9s 10ms/step - loss: 0.2605 - accuracy: 0.9194
# Epoch 59/100
# 938/938 [==============================] - 9s 10ms/step - loss: 0.2563 - accuracy: 0.9202
# Epoch 60/100
# 938/938 [==============================] - 9s 10ms/step - loss: 0.2636 - accuracy: 0.9178
# Epoch 61/100
# 938/938 [==============================] - 9s 10ms/step - loss: 0.2681 - accuracy: 0.9180
# Epoch 62/100
# 938/938 [==============================] - 9s 10ms/step - loss: 0.2676 - accuracy: 0.9172
# Epoch 63/100
# 938/938 [==============================] - 9s 10ms/step - loss: 0.2628 - accuracy: 0.9199
# Epoch 64/100
# 938/938 [==============================] - 9s 10ms/step - loss: 0.2605 - accuracy: 0.9224
# Epoch 65/100
# 938/938 [==============================] - 9s 10ms/step - loss: 0.2696 - accuracy: 0.9202
# Epoch 66/100
# 938/938 [==============================] - 9s 10ms/step - loss: 0.2624 - accuracy: 0.9204
# Epoch 67/100
# 938/938 [==============================] - 9s 10ms/step - loss: 0.2710 - accuracy: 0.9180
# Epoch 68/100
# 938/938 [==============================] - 10s 10ms/step - loss: 0.2592 - accuracy: 0.9226
# Epoch 69/100
# 938/938 [==============================] - 10s 10ms/step - loss: 0.2611 - accuracy: 0.9210
# Epoch 70/100
# 938/938 [==============================] - 9s 10ms/step - loss: 0.2676 - accuracy: 0.9192
# Epoch 71/100
# 938/938 [==============================] - 9s 10ms/step - loss: 0.2689 - accuracy: 0.9185
# Epoch 72/100
# 938/938 [==============================] - 9s 10ms/step - loss: 0.2703 - accuracy: 0.9193
# Epoch 73/100
# 938/938 [==============================] - 9s 10ms/step - loss: 0.2713 - accuracy: 0.9189
# Epoch 74/100
# 938/938 [==============================] - 9s 10ms/step - loss: 0.2744 - accuracy: 0.9162
# Epoch 75/100
# 938/938 [==============================] - 9s 10ms/step - loss: 0.2720 - accuracy: 0.9167
# Epoch 76/100
# 938/938 [==============================] - 9s 10ms/step - loss: 0.2711 - accuracy: 0.9169
# Epoch 77/100
# 938/938 [==============================] - 9s 10ms/step - loss: 0.2727 - accuracy: 0.9168
# Epoch 78/100
# 938/938 [==============================] - 9s 10ms/step - loss: 0.2764 - accuracy: 0.9159
# Epoch 79/100
# 938/938 [==============================] - 9s 10ms/step - loss: 0.2588 - accuracy: 0.9209
# Epoch 80/100
# 938/938 [==============================] - 9s 10ms/step - loss: 0.2538 - accuracy: 0.9210
# Epoch 81/100
# 938/938 [==============================] - 9s 10ms/step - loss: 0.2407 - accuracy: 0.9250
# Epoch 82/100
# 938/938 [==============================] - 9s 10ms/step - loss: 0.2327 - accuracy: 0.9286
# Epoch 83/100
# 938/938 [==============================] - 9s 10ms/step - loss: 0.2369 - accuracy: 0.9280
# Epoch 84/100
# 938/938 [==============================] - 9s 10ms/step - loss: 0.2426 - accuracy: 0.9276
# Epoch 85/100
# 938/938 [==============================] - 9s 10ms/step - loss: 0.2373 - accuracy: 0.9284
# Epoch 86/100
# 938/938 [==============================] - 9s 10ms/step - loss: 0.2452 - accuracy: 0.9265
# Epoch 87/100
# 938/938 [==============================] - 9s 10ms/step - loss: 0.2380 - accuracy: 0.9283
# Epoch 88/100
# 938/938 [==============================] - 9s 10ms/step - loss: 0.2349 - accuracy: 0.9274
# Epoch 89/100
# 938/938 [==============================] - 9s 10ms/step - loss: 0.2346 - accuracy: 0.9281
# Epoch 90/100
# 938/938 [==============================] - 9s 10ms/step - loss: 0.2404 - accuracy: 0.9277
# Epoch 91/100
# 938/938 [==============================] - 9s 10ms/step - loss: 0.2408 - accuracy: 0.9274
# Epoch 92/100
# 938/938 [==============================] - 9s 10ms/step - loss: 0.2425 - accuracy: 0.9283
# Epoch 93/100
# 938/938 [==============================] - 9s 10ms/step - loss: 0.2453 - accuracy: 0.9263
# Epoch 94/100
# 938/938 [==============================] - 9s 10ms/step - loss: 0.2422 - accuracy: 0.9274
# Epoch 95/100
# 938/938 [==============================] - 9s 10ms/step - loss: 0.2462 - accuracy: 0.9268
# Epoch 96/100
# 938/938 [==============================] - 9s 10ms/step - loss: 0.2518 - accuracy: 0.9233
# Epoch 97/100
# 938/938 [==============================] - 10s 10ms/step - loss: 0.2549 - accuracy: 0.9250
# Epoch 98/100
# 938/938 [==============================] - 9s 10ms/step - loss: 0.2559 - accuracy: 0.9242
# Epoch 99/100
# 938/938 [==============================] - 10s 10ms/step - loss: 0.2586 - accuracy: 0.9227
# Epoch 100/100
# 938/938 [==============================] - 9s 10ms/step - loss: 0.2521 - accuracy: 0.9247

# %%
score = model.evaluate(x_test, y_test, verbose=0)
print("Test loss:", score[0])
print("Test accuracy:", score[1])
# Out:
# Test loss: 0.12829552590847015
# Test accuracy: 0.9595000147819519

# %%
model.save("bin_mnist_conv2_TRAINED.h5")
